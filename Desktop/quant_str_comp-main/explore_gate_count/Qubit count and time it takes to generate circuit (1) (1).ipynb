# %% [markdown]
# ### Qubit count and time it takes to generate circuit

# %%
max_state = 20
n_qubit_state = [i for i in range(1, max_state)]

# %%
#Quantum State Preparation with Optimal Circuit Depth: Implementations and Applications
qubit_count_1 = []
time_to_generate_circuit_1 = []
for i in n_qubit_state:
    qubit_count_1.append(2 ** i)
    time_to_generate_circuit_1.append( 2 ** i)

# %%
#Asymptotically Optimal Circuit Depth for Quantum State Preparation and General Unitary Synthesis
qubit_count_2 = []
time_to_generate_circuit_2 = []
for i in n_qubit_state:
    qubit_count_2.append(2 ** i)
    time_to_generate_circuit_2.append( 2 ** i)

# %%
#A divide‐and‐conquer algorithm for quantum state preparation
qubit_count_3 = []
time_to_generate_circuit_3 = []
for i in n_qubit_state:
    qubit_count_3.append(2 ** i)
    time_to_generate_circuit_3.append( 2 ** i)

# %%
#Low-depth quantum state preparation unitary
qubit_count_4 = []
time_to_generate_circuit_4 = []
for i in n_qubit_state:
    qubit_count_4.append(i)
    time_to_generate_circuit_4.append( 2 ** i)

# %%
#Low-depth quantum state preparation sequential
qubit_count_5 = []
time_to_generate_circuit_5 = []
for i in n_qubit_state:
    qubit_count_5.append(i)
    time_to_generate_circuit_5.append( 2 ** ( 2 * i))

# %%
#Low-depth quantum state preparation Prallel1
qubit_count_6= []
time_to_generate_circuit_6 = []
for i in n_qubit_state:
    qubit_count_6.append( 2 ** ( 2 * i))
    time_to_generate_circuit_6.append( i ** 2)

# %%
#Low-depth quantum state preparation Prallel2
qubit_count_7= []
time_to_generate_circuit_7 = []
for i in n_qubit_state:
    qubit_count_7.append( 2 ** i)
    time_to_generate_circuit_7.append( (2**i)**1.52)

# %%
#qubit count
import matplotlib.pyplot as plt

plt.xlabel("n-qubit state")
plt.ylabel("qubit count")
plt.yscale('log')
plt.plot(n_qubit_state, qubit_count_7, label = "qubit_count Low-depth quantum state preparation Prallel2")
plt.plot(n_qubit_state, qubit_count_6, label = "qubit_count Low-depth quantum state preparation Prallel1")
plt.plot(n_qubit_state, qubit_count_5, label = "Low-depth quantum state preparation sequential")
plt.plot(n_qubit_state, qubit_count_4, label = "Low-depth quantum state preparation unitary")
plt.plot(n_qubit_state, qubit_count_3, label = "A divide‐and‐conquer algorithm for quantum state preparation")
plt.plot(n_qubit_state, qubit_count_2, label = "Asymptotically Optimal Circuit Depth for Quantum State Preparation and General Unitary Synthesis")
plt.plot(n_qubit_state, qubit_count_1, label = "Quantum State Preparation with Optimal Circuit Depth: Implementations and Applications")





plt.legend()
plt.show()

# %%
#Time it takes to prepare circuit  
plt.xlabel("n-qubit state")
plt.ylabel("time it takes to generate circuit")
plt.yscale('log')
plt.plot(n_qubit_state, time_to_generate_circuit_7, label = "qubit_count Low-depth quantum state preparation Prallel2")
plt.plot(n_qubit_state, time_to_generate_circuit_6, label = "qubit_count Low-depth quantum state preparation Prallel1")
plt.plot(n_qubit_state, time_to_generate_circuit_5, label = "Low-depth quantum state preparation sequential")
plt.plot(n_qubit_state, time_to_generate_circuit_4, label = "Low-depth quantum state preparation unitary")
plt.plot(n_qubit_state, time_to_generate_circuit_3, label = "A divide‐and‐conquer algorithm for quantum state preparation")
plt.plot(n_qubit_state, time_to_generate_circuit_2, label = "Asymptotically Optimal Circuit Depth for Quantum State Preparation and General Unitary Synthesis")
plt.plot(n_qubit_state, time_to_generate_circuit_1, label = "Quantum State Preparation with Optimal Circuit Depth: Implementations and Applications")





plt.legend()
plt.show()

# %% [markdown]
# ### Circuit Depth

# %%
#Quantum State Preparation with Optimal Circuit Depth: Implementations and Applications
circuit_depth_1 = []
for i in n_qubit_state:
    circuit_depth_1.append(i)

# %%
#Asymptotically Optimal Circuit Depth for Quantum State Preparation and General Unitary Synthesis
import math
circuit_depth_2 = []
for i in n_qubit_state:
    circuit_depth_2.append((i * math.log(i)) + (((2**i) /(i + 2 ** i))))

# %%
# A divide-and-conquer algorithm for quantum state preparation
circuit_depth_3 = []
for i in n_qubit_state:
    circuit_depth_3.append(2 ** i)

# %%
# A divide-and-conquer algorithm for quantum state preparation
circuit_depth_3 = []
for i in n_qubit_state:
    circuit_depth_3.append(2 ** i)

# %%
#Low-depth quantum state preparation unitary
circuit_depth_4 = []
for i in n_qubit_state:
    circuit_depth_4.append(2 ** i)

# %%
#Low-depth quantum state preparation sequential
circuit_depth_5 = []
for i in n_qubit_state:
    circuit_depth_5.append(i ** 2)

# %%
#Low-depth quantum state preparation parallel1
circuit_depth_6 = []
for i in n_qubit_state:
    circuit_depth_6.append(i ** 2)

# %%
#Low-depth quantum state preparation parallel2
circuit_depth_7 = []
for i in n_qubit_state:
    circuit_depth_7.append(i ** 2)

# %%
#Time it takes to prepare circuit  
plt.xlabel("n-qubit state")
plt.ylabel("circuit depth")
plt.yscale('log')
plt.plot(n_qubit_state, circuit_depth_7, label = "qubit_count Low-depth quantum state preparation Prallel2")
plt.plot(n_qubit_state, circuit_depth_6, label = "qubit_count Low-depth quantum state preparation Prallel1")
plt.plot(n_qubit_state, circuit_depth_5, label = "Low-depth quantum state preparation sequential")
plt.plot(n_qubit_state, circuit_depth_4, label = "Low-depth quantum state preparation unitary")
plt.plot(n_qubit_state, circuit_depth_3, label = "A divide‐and‐conquer algorithm for quantum state preparation")
plt.plot(n_qubit_state, circuit_depth_2, label = "Asymptotically Optimal Circuit Depth for Quantum State Preparation and General Unitary Synthesis")
plt.plot(n_qubit_state, circuit_depth_1, label = "Quantum State Preparation with Optimal Circuit Depth: Implementations and Applications")





plt.legend()
plt.show()
